# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from datetime import datetime, timedelta
import re

# %%
# Function to create a DataFrame from a JSON URL
def create_df_from_json_url(url):
  response = requests.get(url)
  data = json.loads(response.text)
  df = pd.json_normalize(data, record_path=['events'])
  return df
def convert_events_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%A, %B %d, %Y', errors='raise')
    except ValueError:
        # format is Monday, April 21 2025, change format
        return pd.to_datetime(date_str, format='%A, %b %d %Y', errors='raise')

def convert_events_time(time_str):
    if time_str == 'All Day':
        return pd.to_datetime('00:00:00', format='%H:%M:%S').time()  # Set to midnight for "All Day"
    elif re.match(r'\d{1,2}:\d{2}[ap]m - \d{1,2}:\d{2}[ap]m', time_str):  # Handle ranges
        start_time_str = time_str.split(' - ')[0]
        return pd.to_datetime(start_time_str, format='%I:%M%p').time()
    else:
        try:
            return pd.to_datetime(time_str, format='%I:%M%p').time()
        except ValueError:
            return pd.NaT  # Handle invalid formats

# Create DataFrame for the second JSON file (nyuEventsRaw.json)
events_url = "https://raw.githubusercontent.com/Md905908324/hofhack25/refs/heads/main/nyuEventsRaw.json"
events_df = create_df_from_json_url(events_url)
events_df['date'] = events_df['date'].apply(convert_events_date)
events_df['time'] = events_df['time'].apply(convert_events_time)
events_df['datetime'] = pd.to_datetime(events_df['date'].astype(str) + ' ' + events_df['time'].astype(str), errors='coerce')
events_df = events_df.drop(columns=['date', 'time'])
events_df
# Out:
#                                             name  \
# 0                                  ACF Nationals
# 1                       AMC Virtual Diaper Drive
# 2    Bridge and Spades Meeting & Eboard Election
# 3                     Bridges Mentorship Program
# 4               CBL Doodles; Tea and Joe’s Pizza
# ..                                           ...
# 149                       Ethics Workshop Series
# 150                        Papotons en français!
# 151                       Ethics Workshop Series
# 152                        Papotons en français!
# 153                       Ethics Workshop Series
#
#                           location description            datetime
# 0           University of Maryland         NaN 2025-04-20 00:00:00
# 1    Benefitting Little Essentials         NaN 2025-04-20 00:00:00
# 2                Kimmel 802 Shoren         NaN 2025-04-20 00:00:00
# 3                    Kimmel Rm 375         NaN 2025-04-20 00:00:00
# 4     GLOBAL CTR (Kimmel) - GC 361         NaN 2025-04-20 00:00:00
# ..                             ...         ...                 ...
# 149       Washington Square Campus         NaN 2025-04-21 16:00:00
# 150       Washington Square Campus         NaN 2025-04-22 12:30:00
# 151       Washington Square Campus         NaN 2025-04-22 16:00:00
# 152       Washington Square Campus         NaN 2025-04-23 12:30:00
# 153       Washington Square Campus         NaN 2025-04-23 16:00:00
#
# [154 rows x 4 columns]

# %%
engage_url = "https://raw.githubusercontent.com/Md905908324/hofhack25/refs/heads/main/nyuEngageRaw.json"
engage_df = create_df_from_json_url(engage_url)

def convert_date(date_str):
    # Remove the time zone abbreviation (e.g., EDT)
    date_str = re.sub(r" EDT| EST", "", date_str)
    # Add the year 2025 to the date string
    date_str = date_str + " 2025"
    # Parse the date and time
    return pd.to_datetime(date_str, format='%A, %B %d at %I:%M%p %Y')

engage_df['date'] = engage_df['date'].apply(convert_date)
engage_df = engage_df.rename(columns={'date': 'datetime'})

# %%
engage_df
# Out:
#                                                  name            datetime  \
# 0             Volunteer at Tompkins Distro w/ CAS ISC 2025-04-19 09:00:00
# 1                           E Board Gathering Meeting 2025-04-19 11:00:00
# 2   Taiwanese Student Association - All-University... 2025-04-19 11:00:00
# 3                                       Peer Tutoring 2025-04-19 11:00:00
# 4   Society for Women in Sports - All-University M... 2025-04-19 11:00:00
# ..                                                ...                 ...
# 81                 English Conversation Group Meeting 2025-04-23 19:15:00
# 82                                    Finding Purpose 2025-04-23 18:30:00
# 83                             Weekly Writers Meeting 2025-04-23 18:30:00
# 84                                     Orevwa Chérie! 2025-04-23 18:30:00
# 85  Cross-Examination Debate Association - General... 2025-04-23 19:30:00
#
#                                          location  \
# 0                            Tompkins Square Park
# 1                                          Online
# 2                                          Online
# 3                                   CycleBar Noho
# 4                            6 Metrotech Room 304
# ..                                            ...
# 81                                      GCASL 361
# 82                                 Kimmel CTR 908
# 83                       Kimmel Center - Room 904
# 84                                     Kimmel 905
# 85  Global Center for Academic and Spiritual Life
#
#                    organization  \
# 0                           NaN
# 1   International Students Club
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 81                          NaN
# 82                          NaN
# 83                          NaN
# 84                          NaN
# 85                          NaN
#
#                                                  host
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 81                  Compass Koinonia - All-University
# 82                      Lotus Lounge - All-University
# 83                            Plague - All-University
# 84  Haitian American Students Association - All-Un...
# 85  Cross-Examination Debate Association - All-Uni...
#
# [86 rows x 5 columns]

# %%
combined_df = pd.concat([engage_df, events_df], ignore_index=True)
combined_df
# Out:
#                                                   name            datetime  \
# 0              Volunteer at Tompkins Distro w/ CAS ISC 2025-04-19 09:00:00
# 1                            E Board Gathering Meeting 2025-04-19 11:00:00
# 2    Taiwanese Student Association - All-University... 2025-04-19 11:00:00
# 3                                        Peer Tutoring 2025-04-19 11:00:00
# 4    Society for Women in Sports - All-University M... 2025-04-19 11:00:00
# ..                                                 ...                 ...
# 235                             Ethics Workshop Series 2025-04-21 16:00:00
# 236                              Papotons en français! 2025-04-22 12:30:00
# 237                             Ethics Workshop Series 2025-04-22 16:00:00
# 238                              Papotons en français! 2025-04-23 12:30:00
# 239                             Ethics Workshop Series 2025-04-23 16:00:00
#
#                      location                 organization host description
# 0        Tompkins Square Park                          NaN  NaN         NaN
# 1                      Online  International Students Club  NaN         NaN
# 2                      Online                          NaN  NaN         NaN
# 3               CycleBar Noho                          NaN  NaN         NaN
# 4        6 Metrotech Room 304                          NaN  NaN         NaN
# ..                        ...                          ...  ...         ...
# 235  Washington Square Campus                          NaN  NaN         NaN
# 236  Washington Square Campus                          NaN  NaN         NaN
# 237  Washington Square Campus                          NaN  NaN         NaN
# 238  Washington Square Campus                          NaN  NaN         NaN
# 239  Washington Square Campus                          NaN  NaN         NaN
#
# [240 rows x 6 columns]

# %%
combined_df['All Day'] = combined_df['datetime'].dt.time == pd.to_datetime('00:00:00').time()
combined_df = combined_df.drop(columns=['organization', 'host', 'description'])
combined_df = combined_df.dropna(subset=['datetime'])
combined_df = combined_df.sort_values(by='datetime')
combined_df = combined_df.reset_index(drop=True)
combined_df
# Out:
#                                                   name            datetime  \
# 0     APDA Tournament Hosted by University of Virginia 2025-04-18 15:00:00
# 1    HOF Hacks - 24 hour hackathon with Vercel & Figma 2025-04-18 16:30:00
# 2              Volunteer at Tompkins Distro w/ CAS ISC 2025-04-19 09:00:00
# 3                                        Peer Tutoring 2025-04-19 11:00:00
# 4                            E Board Gathering Meeting 2025-04-19 11:00:00
# ..                                                 ...                 ...
# 220                   Muslim Voices for Social Justice 2025-04-23 19:00:00
# 221                 English Conversation Group Meeting 2025-04-23 19:15:00
# 222          Spring Jazz Festival: Vocal Jazz Ensemble 2025-04-23 19:30:00
# 223  Cross-Examination Debate Association - General... 2025-04-23 19:30:00
# 224                          Steinhardt Open Mic Night 2025-04-23 20:00:00
#
#                                           location  All Day
# 0                           University of Virginia    False
# 1                               HOF Capital NYC HQ    False
# 2                             Tompkins Square Park    False
# 3                                    CycleBar Noho    False
# 4                                           Online    False
# ..                                             ...      ...
# 220                                  Kimmel Center    False
# 221                                      GCASL 361    False
# 222                        Frederick Loewe Theatre    False
# 223  Global Center for Academic and Spiritual Life    False
# 224                            Pless Hall Basement    False
#
# [225 rows x 4 columns]

# %%
combined_df.to_csv('combined_data.csv', index=False)
